# %% [markdown]
# #                               Credit Card Fraud Prediction
# #### Dataset link: https://www.kaggle.com/mlg-ulb/creditcardfraud
#
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# The dataset contains transactions made by credit cards in September 2013 by European cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# #### Tasks:
#
# * Out of all the 30 independent input variables, find the variables that are most useful in predicting ‘Class’.
# * Try implementing PCA (whether it is useful or not) to reduce no. of independent variables.
# * Draft the following classification models to predict ‘Class’: Logistic regression, SVC, Decision Tree Classifier. Write a detailed explanation of each of the models.

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn import metrics

# %% [markdown]
# ### Out of all the 30 independent input variables, find the variables that are most useful in predicting ‘Class’.

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
plt.figure(figsize = (30,28))
corr = df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
classes=df['Class'].value_counts()
classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
normal_share=classes[0]/df['Class'].count()*100
fraud_share=classes[1]/df['Class'].count()*100
print('Normal percentage',normal_share)
print('Fraud percentage',fraud_share)
# Out:
# Normal percentage 99.82725143693798
# Fraud percentage 0.1727485630620034

# %%
X = df.drop("Class",axis = 1)
Y = df["Class"]

# %% [markdown]
# ### Try implementing PCA (whether it is useful or not) to reduce no. of independent variables.

# %% [markdown]
# ### StandardScaler

# %%
#StandardScaler
x = StandardScaler().fit_transform(X)

# %%
#Determining principal componant
pca = PCA(n_components=2)
principalcomponants = pca.fit_transform(x)
principaldf = pd.DataFrame(data=principalcomponants,columns = ["PC1","PC2"])
principaldf.head()
# Out:
#         PC1       PC2
# 0  0.422286 -2.502851
# 1 -0.388225 -2.086621
# 2  1.874031 -2.478480
# 3  0.326277 -1.824416
# 4 -0.013707 -1.479775

# %%
#Getting the final dataframe
FinalDf=pd.concat([principaldf,df[["Class"]]],axis=1)
FinalDf.head()
# Out:
#         PC1       PC2  Class
# 0  0.422286 -2.502851      0
# 1 -0.388225 -2.086621      0
# 2  1.874031 -2.478480      0
# 3  0.326277 -1.824416      0
# 4 -0.013707 -1.479775      0

# %%
FinalDf[FinalDf['Class']==1]
# Out:
#              PC1       PC2  Class
# 541    -0.516091 -2.309930      1
# 623     2.575299 -1.762214      1
# 4920    0.769113 -2.667891      1
# 6108   -0.243120 -2.913966      1
# 6329   -0.542248 -1.709013      1
# ...          ...       ...    ...
# 279863  1.693419  1.188561      1
# 280143 -0.592898  1.872165      1
# 280149 -0.176643  1.879469      1
# 281144  0.869675  1.860139      1
# 281674 -0.347007  2.264176      1
#
# [492 rows x 3 columns]

# %%
# Visualization
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0,1]
colors = ['r', 'g']
for Class, color in zip(targets,colors):
    indicesToKeep = FinalDf['Class'] == Class
    ax.scatter(FinalDf.loc[indicesToKeep, 'PC1']
               , FinalDf.loc[indicesToKeep, 'PC2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### Draft the following classification models to predict ‘Class’: Logistic regression, SVC, Decision Tree Classifier. Write a detailed explanation of each of the models.

# %%
# Separating x and y
Feature = FinalDf[['PC1','PC2']]
Target = FinalDf['Class']

# %%
#Train test split
X_train,X_test,Y_train,Y_test=train_test_split(Feature,Target,test_size= 0.2,random_state=4)

# %% [markdown]
# ### logistic regression

# %%
#Creating logistic regression model
model = LogisticRegression()

#fitting the model
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#predicting from model
Y_pred=model.predict(X_test)

# %%
#Accuracy
print("Accuracy:",metrics.accuracy_score(Y_test,Y_pred)*100)
# Out:
# Accuracy: 99.82268881008392

# %%
#classification_report
print(metrics.classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.00      0.00      0.00       101
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
# C:\Users\SAHIL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## SVC

# %%
#Creating SVM regression
model = svm.SVC(kernel ='linear')

#Fitting the model
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
#predicting from model
Y_pred=model.predict(X_test)

# %%
#Accuracy
print("Accuracy:",metrics.accuracy_score(Y_test,Y_pred)*100)
# Out:
# Accuracy: 99.82268881008392

# %%
#classification_report
print(metrics.classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.00      0.00      0.00       101
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# weighted avg       1.00      1.00      1.00     56962
# C:\Users\SAHIL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Decision tree model

# %%
#Creating Decision Tree Classifier
model = DecisionTreeClassifier()

#Fitting the model
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Predictions
Y_pred=model.predict(X_test)

# %%
#Find accurcy
print("Accuracy:",metrics.accuracy_score(Y_test,Y_pred)*100)
# Out:
# Accuracy: 99.65064428917523

# %%
#classification_report
print(metrics.classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.07      0.08      0.07       101
#
#     accuracy                           1.00     56962
#    macro avg       0.53      0.54      0.54     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# #### Precision and recall value of Decision tree classifier is high as compair to other two classification models. That means Decision tree classifier gives accurate prediction. So Decision tree classifier is best for this dataset.
